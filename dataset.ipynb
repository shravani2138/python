# %%
import pandas as pd

# %%
df=pd.read_csv('my.csv')

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.sample(6)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2548  9796-BPKIW    Male              1      No         No       8
# 2054  9734-UYXQI  Female              0      No         No       2
# 4239  6481-LXPWL    Male              0     Yes        Yes      56
# 2501  6585-WCEWR    Male              0     Yes        Yes      72
# 1850  3537-RYBHH  Female              1     Yes         No      47
# 4783  8760-ZRHKE  Female              1     Yes        Yes      71
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 2548          Yes                No     Fiber optic                   No  ...
# 2054          Yes               Yes             DSL                   No  ...
# 4239           No  No phone service             DSL                   No  ...
# 2501          Yes                No              No  No internet service  ...
# 1850          Yes               Yes             DSL                  Yes  ...
# ...

# %%
import numpy as np 
l1=[1,2,3,4,5,6]
l2=[2,3,4,5,6,7]
na1=np.array(l1)
na2=np.array(l2)
na3=na1+na2
print("na3 : ",na3)
na4=na1+3
print("na4 : ",na4)
print("na1 size : ",na1.size)
# Out:
# na3 :  [ 3  5  7  9 11 13]
# na4 :  [4 5 6 7 8 9]
# na1 size :  6
